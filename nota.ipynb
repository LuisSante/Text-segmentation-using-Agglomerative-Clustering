# %%
import shutil as st
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer, util
from matplotlib import pyplot as plt
import umap.umap_ as umap
import umap.plot as up

# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from bokeh.plotting import show, save, output_notebook, output_file

# %%
# %pip install umap-learn[plot]
# Out:
# Requirement already satisfied: umap-learn[plot] in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (0.5.3)
# Requirement already satisfied: numba>=0.49 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from umap-learn[plot]) (0.55.2)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from umap-learn[plot]) (1.1.1)
# Requirement already satisfied: scipy>=1.0 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from umap-learn[plot]) (1.8.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from umap-learn[plot]) (1.22.4)
# Requirement already satisfied: tqdm in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from umap-learn[plot]) (4.64.0)
# Requirement already satisfied: pynndescent>=0.5 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from umap-learn[plot]) (0.5.7)
# Collecting holoviews
#   Downloading holoviews-1.15.0-py2.py3-none-any.whl (4.3 MB)
#      ---------------------------------------- 4.3/4.3 MB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from umap-learn[plot]) (1.4.2)
# Requirement already satisfied: matplotlib in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from umap-learn[plot]) (3.5.2)
# Collecting datashader
#   Downloading datashader-0.14.1-py2.py3-none-any.whl (18.2 MB)
#      ---------------------------------------- 18.2/18.2 MB 3.9 MB/s eta 0:00:00
# Collecting colorcet
#   Downloading colorcet-3.0.0-py2.py3-none-any.whl (1.6 MB)
#      ---------------------------------------- 1.6/1.6 MB 5.3 MB/s eta 0:00:00
# Collecting seaborn
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
#      -------------------------------------- 292.8/292.8 kB 2.3 MB/s eta 0:00:00
# Collecting bokeh
#   Downloading bokeh-2.4.3-py3-none-any.whl (18.5 MB)
#      ---------------------------------------- 18.5/18.5 MB 5.1 MB/s eta 0:00:00
# Collecting scikit-image
#   Downloading scikit_image-0.19.3-cp310-cp310-win_amd64.whl (12.0 MB)
#      ---------------------------------------- 12.0/12.0 MB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from numba>=0.49->umap-learn[plot]) (58.1.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from numba>=0.49->umap-learn[plot]) (0.38.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from pynndescent>=0.5->umap-learn[plot]) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=0.22->umap-learn[plot]) (3.1.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from bokeh->umap-learn[plot]) (9.1.0)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from bokeh->umap-learn[plot]) (4.2.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from bokeh->umap-learn[plot]) (6.1)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from bokeh->umap-learn[plot]) (3.0.3)
# Requirement already satisfied: packaging>=16.8 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from bokeh->umap-learn[plot]) (21.3)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from bokeh->umap-learn[plot]) (6.0)
# Collecting param>=1.7.0
#   Downloading param-1.12.2-py2.py3-none-any.whl (86 kB)
#      ---------------------------------------- 86.8/86.8 kB 1.2 MB/s eta 0:00:00
# Collecting pyct>=0.4.4
#   Downloading pyct-0.4.8-py2.py3-none-any.whl (15 kB)
# Collecting datashape>=0.5.1
#   Downloading datashape-0.5.2.tar.gz (76 kB)
#      ---------------------------------------- 76.5/76.5 kB 1.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting xarray>=0.9.6
#   Downloading xarray-2022.3.0-py3-none-any.whl (870 kB)
#      -------------------------------------- 870.9/870.9 kB 3.7 MB/s eta 0:00:00
# Collecting dask[complete]>=0.18.0
#   Downloading dask-2022.7.0-py3-none-any.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from pandas->umap-learn[plot]) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from pandas->umap-learn[plot]) (2.8.2)
# Collecting pyviz-comms>=0.7.4
#   Downloading pyviz_comms-2.2.0-py2.py3-none-any.whl (42 kB)
#      -------------------------------------- 42.8/42.8 kB 173.9 kB/s eta 0:00:00
# Collecting panel>=0.13.1
#   Downloading panel-0.13.1-py2.py3-none-any.whl (15.7 MB)
#      ---------------------------------------- 15.7/15.7 MB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->umap-learn[plot]) (3.0.8)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->umap-learn[plot]) (4.33.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->umap-learn[plot]) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->umap-learn[plot]) (0.11.0)
# Collecting networkx>=2.2
#   Downloading networkx-2.8.4-py3-none-any.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 5.6 MB/s eta 0:00:00
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2022.5.4-py3-none-any.whl (195 kB)
#      -------------------------------------- 195.6/195.6 kB 1.1 MB/s eta 0:00:00
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.3.0-cp310-cp310-win_amd64.whl (4.2 MB)
#      ---------------------------------------- 4.2/4.2 MB 4.6 MB/s eta 0:00:00
# Collecting imageio>=2.4.1
#   Downloading imageio-2.19.3-py3-none-any.whl (3.4 MB)
#      ---------------------------------------- 3.4/3.4 MB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from tqdm->umap-learn[plot]) (0.4.4)
# Collecting cloudpickle>=1.1.1
#   Downloading cloudpickle-2.1.0-py3-none-any.whl (25 kB)
# Collecting toolz>=0.8.2
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      -------------------------------------- 55.8/55.8 kB 970.1 kB/s eta 0:00:00
# Collecting partd>=0.3.10
#   Downloading partd-1.2.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: fsspec>=0.6.0 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from dask[complete]>=0.18.0->datashader->umap-learn[plot]) (2022.3.0)
# Collecting distributed==2022.7.0
#   Downloading distributed-2022.7.0-py3-none-any.whl (885 kB)
#      -------------------------------------- 885.6/885.6 kB 4.7 MB/s eta 0:00:00
# Collecting tblib>=1.6.0
#   Downloading tblib-1.7.0-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: click>=6.6 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from distributed==2022.7.0->dask[complete]>=0.18.0->datashader->umap-learn[plot]) (8.0.3)
# Collecting sortedcontainers!=2.0.0,!=2.0.1
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Collecting locket>=1.0.0
#   Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: psutil>=5.0 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from distributed==2022.7.0->dask[complete]>=0.18.0->datashader->umap-learn[plot]) (5.9.1)
# Collecting zict>=0.1.3
#   Downloading zict-2.2.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: urllib3 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from distributed==2022.7.0->dask[complete]>=0.18.0->datashader->umap-learn[plot]) (1.26.7)
# Collecting msgpack>=0.6.0
#   Downloading msgpack-1.0.4-cp310-cp310-win_amd64.whl (61 kB)
#      --------------------------------------- 61.3/61.3 kB 38.5 kB/s eta 0:00:00
# Collecting multipledispatch>=0.4.7
#   Downloading multipledispatch-0.6.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from Jinja2>=2.9->bokeh->umap-learn[plot]) (2.0.1)
# Requirement already satisfied: bleach in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from panel>=0.13.1->holoviews->umap-learn[plot]) (5.0.0)
# Requirement already satisfied: markdown in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from panel>=0.13.1->holoviews->umap-learn[plot]) (3.3.7)
# Requirement already satisfied: requests in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from panel>=0.13.1->holoviews->umap-learn[plot]) (2.26.0)
# Requirement already satisfied: six>=1.5 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas->umap-learn[plot]) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from bleach->panel>=0.13.1->holoviews->umap-learn[plot]) (0.5.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from requests->panel>=0.13.1->holoviews->umap-learn[plot]) (2.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from requests->panel>=0.13.1->holoviews->umap-learn[plot]) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\usuario\appdata\local\programs\python\python310\lib\site-packages (from requests->panel>=0.13.1->holoviews->umap-learn[plot]) (3.3)
# Collecting heapdict
#   Downloading HeapDict-1.0.1-py3-none-any.whl (3.9 kB)
# Building wheels for collected packages: datashape
#   Building wheel for datashape (setup.py): started
#   Building wheel for datashape (setup.py): finished with status 'done'
#   Created wheel for datashape: filename=datashape-0.5.2-py3-none-any.whl size=59453 sha256=4a81b3121146b1e69e105da350f49031c126ff75d81cd02ed5265951dbdbeb28
#   Stored in directory: c:\users\usuario\appdata\local\pip\cache\wheels\35\c6\63\a3c12ecc9fdea10a593271de5c56481b427ad4049b90a176e1
# Successfully built datashape
# Installing collected packages: sortedcontainers, msgpack, heapdict, zict, toolz, tifffile, tblib, PyWavelets, param, networkx, multipledispatch, locket, imageio, cloudpickle, scikit-image, pyviz-comms, pyct, partd, datashape, bokeh, xarray, seaborn, panel, dask, colorcet, holoviews, distributed, datashader
# Successfully installed PyWavelets-1.3.0 bokeh-2.4.3 cloudpickle-2.1.0 colorcet-3.0.0 dask-2022.7.0 datashader-0.14.1 datashape-0.5.2 distributed-2022.7.0 heapdict-1.0.1 holoviews-1.15.0 imageio-2.19.3 locket-1.0.0 msgpack-1.0.4 multipledispatch-0.6.0 networkx-2.8.4 panel-0.13.1 param-1.12.2 partd-1.2.0 pyct-0.4.8 pyviz-comms-2.2.0 scikit-image-0.19.3 seaborn-0.11.2 sortedcontainers-2.4.0 tblib-1.7.0 tifffile-2022.5.4 toolz-0.12.0 xarray-2022.3.0 zict-2.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
dataset = fetch_20newsgroups(subset='all' , shuffle=True)
dataset.target_names
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %%
category_labels = [dataset.target_names[x] for x in dataset.target]
hover_df = pd.DataFrame(category_labels, columns = ['category'])

# %%
vectorizer = CountVectorizer(min_df=5, stop_words='english')
word_doc_matrix = vectorizer.fit_transform(dataset.data)

# %%
embedding = umap.UMAP(n_components=2, metric='cosine').fit(word_doc_matrix)

# %%
f = up.points(embedding, labels=hover_df['category'])
